# %%
import json
import string
import random
from flask import Flask, request, jsonify
from flask_cors import CORS

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import nltk
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
data_file = open('intents_new.json').read()
data = json.loads(data_file)

# %%
words = []
classes = []
data_X = []
data_y = []

for intent in data["intents"]:
  for pattern in intent["patterns"]:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_X.append(pattern)
    data_y.append(intent["tag"]),
  if intent["tag"] not in classes:
    classes.append(intent["tag"])

lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_X):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])] = 1
  training.append([bow, output_row])
random.shuffle(training)
training = np.array(training, dtype=object)
train_X = np.array(list(training[:,0]))
train_Y = np.array(list(training[:,1]))

# %%
model = Sequential()
model.add(Dense(128, input_shape = (len(train_X[0]),), activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate = 0.01, decay = 1e-6)
model.compile(loss = "categorical_crossentropy",
              optimizer = adam,
              metrics = ["accuracy"]
              )
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs = 150, verbose = 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7168
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 15,944
# Trainable params: 15,944
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 4ms/step - loss: 2.0480 - accuracy: 0.2222
# Epoch 2/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9069 - accuracy: 0.3333
# Epoch 3/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7516 - accuracy: 0.4722
# Epoch 4/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6181 - accuracy: 0.4722
# Epoch 5/150
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3963 - accuracy: 0.6389
# Epoch 6/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3390 - accuracy: 0.6667
# Epoch 7/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2160 - accuracy: 0.6667
# Epoch 8/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9835 - accuracy: 0.6944
# Epoch 9/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8430 - accuracy: 0.7778
# Epoch 10/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7973 - accuracy: 0.7222
# Epoch 11/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6996 - accuracy: 0.7778
# Epoch 12/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7428 - accuracy: 0.7778
# Epoch 13/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5905 - accuracy: 0.8333
# Epoch 14/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7223 - accuracy: 0.8333
# Epoch 15/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3298 - accuracy: 0.9167
# Epoch 16/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4303 - accuracy: 0.8889
# Epoch 17/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3780 - accuracy: 0.8333
# Epoch 18/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3750 - accuracy: 0.8889
# Epoch 19/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3223 - accuracy: 0.8889
# Epoch 20/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.9167
# Epoch 21/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1261 - accuracy: 0.9722
# Epoch 22/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2250 - accuracy: 0.9444
# Epoch 23/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1540 - accuracy: 0.9722
# Epoch 24/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 1.0000
# Epoch 25/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3055 - accuracy: 0.8611
# Epoch 26/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1685 - accuracy: 0.9722
# Epoch 27/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 1.0000
# Epoch 28/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2067 - accuracy: 0.9444
# Epoch 29/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9167
# Epoch 30/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1346 - accuracy: 0.9722
# Epoch 31/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9444
# Epoch 32/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1146 - accuracy: 0.9444
# Epoch 33/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.9444
# Epoch 34/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.9444
# Epoch 35/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1511 - accuracy: 0.9444
# Epoch 36/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1422 - accuracy: 0.9444
# Epoch 37/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9167
# Epoch 38/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9722
# Epoch 39/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0877 - accuracy: 0.9722
# Epoch 40/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 41/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 42/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 43/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9722
# Epoch 44/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1207 - accuracy: 0.9722
# Epoch 45/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9444
# Epoch 46/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9167
# Epoch 47/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 48/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1866 - accuracy: 0.9444
# Epoch 49/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 50/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9722
# Epoch 51/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 52/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0847 - accuracy: 1.0000
# Epoch 53/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 54/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1128 - accuracy: 0.9722
# Epoch 55/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 56/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 1.0000
# Epoch 57/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9722
# Epoch 58/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 59/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0795 - accuracy: 0.9722
# Epoch 60/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 61/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9722
# Epoch 62/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 63/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 64/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 65/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.9722
# Epoch 66/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 67/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9722
# Epoch 68/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9722
# Epoch 69/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 70/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9722
# Epoch 71/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9722
# Epoch 73/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 74/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 75/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9722
# Epoch 76/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1648 - accuracy: 0.9167
# Epoch 77/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 78/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0432 - accuracy: 0.9722
# Epoch 79/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 80/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 81/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2076 - accuracy: 0.9167
# Epoch 82/150
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0516 - accuracy: 0.9722
# Epoch 83/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 84/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0505 - accuracy: 0.9722
# Epoch 85/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0861 - accuracy: 0.9444
# Epoch 86/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9722
# Epoch 87/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 88/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0675 - accuracy: 0.9722
# Epoch 89/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 91/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0363 - accuracy: 0.9722
# Epoch 92/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9722
# Epoch 93/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 94/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9722
# Epoch 95/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 96/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 97/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 98/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 99/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 100/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9722
# Epoch 101/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 102/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0698 - accuracy: 0.9722
# Epoch 103/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 104/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 105/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 106/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 107/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 108/150
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 109/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 110/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 111/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 112/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0748 - accuracy: 0.9722
# Epoch 113/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9722
# Epoch 114/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 115/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 116/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9722
# Epoch 117/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 118/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 119/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 121/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 122/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 123/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 124/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 125/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 126/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9722
# Epoch 127/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 128/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 130/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9722
# Epoch 131/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 132/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9722
# Epoch 133/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 134/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 135/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 136/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 137/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 139/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 140/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 141/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 142/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 143/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 144/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 145/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 146/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0403 - accuracy: 0.9722
# Epoch 147/150
# 2/2 [==============================] - 0s 6ms/step - loss: 8.0653e-04 - accuracy: 1.0000
# Epoch 148/150
# 2/2 [==============================] - 0s 5ms/step - loss: 9.8352e-04 - accuracy: 1.0000
# Epoch 149/150
# 2/2 [==============================] - 0s 5ms/step - loss: 8.9593e-04 - accuracy: 1.0000
# Epoch 150/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0804 - accuracy: 0.9722

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
    return return_list
  
def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents= intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
app = Flask(__name__)
CORS(app)

@app.route('/chat', methods=['POST'])
def chat():
    message = request.json['message']
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    response = jsonify({'response': result})
    response.headers.add('Access-Control-Allow-Origin', '*')
    return response

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 1/1 [==============================] - 0s 142ms/step
# 127.0.0.1 - - [15/May/2023 03:11:01] "POST /chat HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 03:11:07] "OPTIONS /chat HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 29ms/step
# 127.0.0.1 - - [15/May/2023 03:11:07] "POST /chat HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 03:11:16] "OPTIONS /chat HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 25ms/step
# 127.0.0.1 - - [15/May/2023 03:11:16] "POST /chat HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2548, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\PercyGFX\AppData\Local\Temp\ipykernel_17340\3633340550.py", line 8, in chat
#     result = get_response(intents, data)
#   File "C:\Users\PercyGFX\AppData\Local\Temp\ipykernel_17340\894967600.py", line 27, in get_response
#     if len(intents_list) == 0:
# TypeError: object of type 'NoneType' has no len()
# 127.0.0.1 - - [15/May/2023 03:11:26] "OPTIONS /chat HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 23ms/step
# 127.0.0.1 - - [15/May/2023 03:11:26] "POST /chat HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2548, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\ProgramData\anaconda3\lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\PercyGFX\AppData\Local\Temp\ipykernel_17340\3633340550.py", line 8, in chat
#     result = get_response(intents, data)
#   File "C:\Users\PercyGFX\AppData\Local\Temp\ipykernel_17340\894967600.py", line 27, in get_response
#     if len(intents_list) == 0:
# TypeError: object of type 'NoneType' has no len()
