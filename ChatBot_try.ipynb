# %%
import json
import string
import random
from flask import Flask, request, jsonify

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import nltk
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\PercyGFX\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
data_file = open('intents_new.json').read()
data = json.loads(data_file)

# %%
words = []
classes = []
data_X = []
data_y = []

for intent in data["intents"]:
  for pattern in intent["patterns"]:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_X.append(pattern)
    data_y.append(intent["tag"]),
  if intent["tag"] not in classes:
    classes.append(intent["tag"])

lemmatizer = WordNetLemmatizer()

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_X):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  output_row = list(out_empty)
  output_row[classes.index(data_y[idx])] = 1
  training.append([bow, output_row])
random.shuffle(training)
training = np.array(training, dtype=object)
train_X = np.array(list(training[:,0]))
train_Y = np.array(list(training[:,1]))

# %%
model = Sequential()
model.add(Dense(128, input_shape = (len(train_X[0]),), activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.legacy.Adam(learning_rate = 0.01, decay = 1e-6)
model.compile(loss = "categorical_crossentropy",
              optimizer = adam,
              metrics = ["accuracy"]
              )
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs = 150, verbose = 1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               7168
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 15,944
# Trainable params: 15,944
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 4ms/step - loss: 2.1219 - accuracy: 0.1667
# Epoch 2/150
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9195 - accuracy: 0.2778
# Epoch 3/150
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8240 - accuracy: 0.3889
# Epoch 4/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6793 - accuracy: 0.4722
# Epoch 5/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4644 - accuracy: 0.5833
# Epoch 6/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4778 - accuracy: 0.5278
# Epoch 7/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3552 - accuracy: 0.6111
# Epoch 8/150
# 2/2 [==============================] - 0s 34ms/step - loss: 1.2342 - accuracy: 0.7222
# Epoch 9/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0926 - accuracy: 0.6111
# Epoch 10/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9579 - accuracy: 0.6944
# Epoch 11/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8912 - accuracy: 0.6667
# Epoch 12/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8242 - accuracy: 0.6389
# Epoch 13/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7641 - accuracy: 0.7500
# Epoch 14/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5910 - accuracy: 0.8611
# Epoch 15/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.8056
# Epoch 16/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.8056
# Epoch 17/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.9167
# Epoch 18/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3062 - accuracy: 0.9444
# Epoch 19/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3335 - accuracy: 0.8611
# Epoch 20/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3086 - accuracy: 0.9167
# Epoch 21/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2575 - accuracy: 0.9444
# Epoch 22/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2099 - accuracy: 0.9722
# Epoch 23/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1303 - accuracy: 0.9722
# Epoch 24/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9167
# Epoch 25/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1380 - accuracy: 0.9722
# Epoch 26/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1580 - accuracy: 0.9444
# Epoch 27/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9722
# Epoch 28/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1071 - accuracy: 0.9444
# Epoch 29/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9722
# Epoch 30/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 31/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9444
# Epoch 32/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 1.0000
# Epoch 33/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2444 - accuracy: 0.9444
# Epoch 34/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9444
# Epoch 35/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9167
# Epoch 36/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.8889
# Epoch 37/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9722
# Epoch 38/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9722
# Epoch 39/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 40/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 41/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 42/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9444
# Epoch 43/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9722
# Epoch 44/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 45/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9722
# Epoch 46/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 47/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 48/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 49/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9722
# Epoch 50/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 51/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 52/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9722
# Epoch 53/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 54/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 55/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 56/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 57/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9444
# Epoch 58/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.9444
# Epoch 59/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9722
# Epoch 60/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 61/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 62/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 63/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9722
# Epoch 64/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 65/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 66/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 67/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0695 - accuracy: 0.9722
# Epoch 68/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 69/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0598 - accuracy: 0.9722
# Epoch 70/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 0.9722
# Epoch 71/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 0.9722
# Epoch 73/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 74/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9444
# Epoch 75/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9722
# Epoch 76/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0844 - accuracy: 0.9722
# Epoch 77/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1233 - accuracy: 0.9444
# Epoch 78/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1162 - accuracy: 0.9722
# Epoch 79/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 80/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 81/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0854 - accuracy: 0.9722
# Epoch 82/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 83/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 84/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9722
# Epoch 85/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 86/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 87/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 88/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9722
# Epoch 89/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 91/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9722
# Epoch 92/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 93/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 94/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 95/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 96/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 97/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 98/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 99/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9722
# Epoch 100/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1642 - accuracy: 0.9444
# Epoch 101/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9722
# Epoch 102/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 103/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 104/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 105/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9722
# Epoch 106/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9722
# Epoch 107/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 108/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 109/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9722
# Epoch 110/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 111/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 112/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 113/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 114/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9722
# Epoch 115/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9722
# Epoch 116/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 117/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 118/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 119/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 121/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 0.9722
# Epoch 122/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1419 - accuracy: 0.9444
# Epoch 123/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 124/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 125/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1293 - accuracy: 0.9722
# Epoch 126/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9722
# Epoch 127/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 128/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 130/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 131/150
# 2/2 [==============================] - 0s 3ms/step - loss: 7.5252e-04 - accuracy: 1.0000
# Epoch 132/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 133/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 134/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1058 - accuracy: 0.9444
# Epoch 135/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 136/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0415 - accuracy: 0.9722
# Epoch 137/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 139/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 140/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 141/150
# 2/2 [==============================] - 0s 3ms/step - loss: 7.1744e-04 - accuracy: 1.0000
# Epoch 142/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 143/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 144/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 145/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 146/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 147/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9532e-04 - accuracy: 1.0000
# Epoch 148/150
# 2/2 [==============================] - 0s 4ms/step - loss: 9.8863e-04 - accuracy: 1.0000
# Epoch 149/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 150/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
    return return_list
  
def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents= intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
app = Flask(__name__)

@app.route('/chat', methods=['POST'])
def chat():
    message = request.json['message']
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    return jsonify({'response': result})

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# c:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3468: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
